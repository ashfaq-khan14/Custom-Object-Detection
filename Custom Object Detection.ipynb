# %% [markdown]
# #**Custom Object Detection Model**
# | **Team Members**   | **Responsibilities**               | **LinkedIn Profile**                                       | **GitHub Profile**                                     |
# |---------------------|------------------------------------|-------------------------------------------------------------|--------------------------------------------------------|
# | Mohd Ashfaq         | - Installation of TensorFlow       | [LinkedIn](https://www.linkedin.com/in/ashfaqbinsalim/)     | [GitHub](https://github.com/ashfaq-khan-14)             |
# |                     | - Integration of pre-trained models |                                                             |                                                        |
# | Abdul Hadi Ali      | - Configuration of Protocol Buffers | [LinkedIn](https://www.linkedin.com/in/alhadiali777/)      | [GitHub](https://github.com/Abde-Ali)                   |
# |                     | - Setup of Jupyter Notebooks        |                                                             |                                                        |
# | Shaik Sultan        | - GPU Support and Optimization     | [LinkedIn](https://www.linkedin.com/in/sultanbinazeem/)    | [GitHub](https://github.com/sultanbinazeem)            |
# |                     | - OpenCV Integration               |                                                             |                                                        |
#
#
# ##**Setting Up TensorFlow Object Detection: Installation Prerequisites**
#
# ### 1. **Python:**
#    - Install Python, if not already installed.
#      - [Download Python](https://www.python.org/downloads/)
#
# ### 2. **TensorFlow:**
#    - Install TensorFlow. For object detection, TensorFlow 2.x is recommended.
#      - [TensorFlow Installation Guide](https://www.tensorflow.org/install)
#
# ### 3. **Protobuf:**
#    - Install Protocol Buffers (protobuf). TensorFlow Object Detection API uses protobuf for configuration and object detection models.
#      - [Download Protobuf](https://github.com/protocolbuffers/protobuf/releases)
#      - [Protocol Buffers Installation Guide](https://developers.google.com/protocol-buffers/docs/downloads)
#
# ### 4. **COCO API (Optional, for evaluating on COCO metrics):**
#    - If you plan to evaluate your models on COCO metrics, you'll need the COCO API.
#      - [COCO API GitHub Repository](https://github.com/cocodataset/cocoapi)
#
# ### 5. **TensorFlow Object Detection API:**
#    - Download the TensorFlow Object Detection API from the TensorFlow Models GitHub repository.
#      - [TensorFlow Models GitHub Repository](https://github.com/tensorflow/models)
#      - Clone the repository or download the ZIP file.
#
# ### 6. **Protoc Compiler (for compiling .proto files):**
#    - Download and install the protoc compiler.
#      - [Protocol Buffers Compiler (protoc) Releases](https://github.com/protocolbuffers/protobuf/releases)
#
# ### 7. **Jupyter Notebook (Optional, for running object detection in notebooks):**
#    - If you prefer to work with object detection in Jupyter Notebooks, install Jupyter.
#      - [Installing Jupyter](https://jupyter.org/install)
#
# ### 8. **GPU Support (Optional, for accelerated training):**
#    - If you have a compatible GPU, consider installing GPU support for TensorFlow.
#      - [TensorFlow GPU Support Guide](https://www.tensorflow.org/install/gpu)
#
# ### 9. **OpenCV (Optional, for image and video processing):**
#    - Install OpenCV for image and video processing.
#      - [OpenCV Installation Guide](https://docs.opencv.org/master/da/df6/tutorial_py_table_of_contents_setup.html)
#
# ```
#
# Remember to check the specific versions and compatibility requirements mentioned in the respective documentation. After installation, you can proceed with setting up the TensorFlow Object Detection API by following the instructions in the TensorFlow Object Detection API [installation guide](https://github.com/tensorflow/models/blob/master/research/object_detection/g3doc/tf2.md).

# %% [markdown]
# ##**Installing tensorflow**

# %%
# !pip install tensorflow

# %% [markdown]
# #**Collect Raw Data**
#  Collect Raw Data and label them with the help of labelimg
#
# 1. labelimg should be open it from  command prompt .
#
# 2. it is required for Labeling the image for Training the Model or making the model Learn
#
#
#
#
# **Raw Data** link: https://drive.google.com/drive/folders/1lptpO5Ojzk03fssOD4euVRZXp5kvfiLL?usp=drive_link

# %%
import shutil
src_dir = '/content/drive/MyDrive/trainingdemo/training_demo'
trgt_dir = '/content/training_demo'
shutil.copytree(src_dir,trgt_dir)
# Out:
# '/content/training_demo'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.15.0

# %% [markdown]
# ## **Cloning TFOD 2.0 Github**

# %%
# !git clone https://github.com/tensorflow/models.git
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 90359, done.
# remote: Counting objects: 100% (152/152), done.
# remote: Compressing objects: 100% (84/84), done.
# remote: Total 90359 (delta 79), reused 139 (delta 68), pack-reused 90207
# Receiving objects: 100% (90359/90359), 608.42 MiB | 22.36 MiB/s, done.
# Resolving deltas: 100% (65096/65096), done.

# %%
pwd
# Out:
# '/content'

# %%
cd /content/models/research
# Out:
# /content/models/research

# %%
pwd
# Out:
# '/content/models/research'

# %%
# !protoc object_detection/protos/*.proto --python_out=.

# %%
# !git clone https://github.com/cocodataset/cocoapi.git
# Out:
# Cloning into 'cocoapi'...
# remote: Enumerating objects: 975, done.
# remote: Total 975 (delta 0), reused 0 (delta 0), pack-reused 975
# Receiving objects: 100% (975/975), 11.72 MiB | 21.40 MiB/s, done.
# Resolving deltas: 100% (576/576), done.

# %%
cd cocoapi/PythonAPI
# Out:
# /content/models/research/cocoapi/PythonAPI

# %%
# !make
# Out:
# python setup.py build_ext --inplace
# running build_ext
# Compiling pycocotools/_mask.pyx because it changed.
# [1/1] Cythonizing pycocotools/_mask.pyx
# /usr/local/lib/python3.10/dist-packages/Cython/Compiler/Main.py:381: FutureWarning: Cython directive 'language_level' not set, using '3str' for now (Py3). This has changed from earlier releases! File: /content/models/research/cocoapi/PythonAPI/pycocotools/_mask.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# building 'pycocotools._mask' extension
# creating build
# creating build/common
# creating build/temp.linux-x86_64-cpython-310
# creating build/temp.linux-x86_64-cpython-310/pycocotools
# ...

# %%
cp -r pycocotools /content/models/research

# %% [markdown]
# ## **Install the Object Detection API**

# %%
cd ..
# Out:
# /content/models/research/cocoapi

# %%
cd ..
# Out:
# /content/models/research

# %%
cp object_detection/packages/tf2/setup.py .

# %%
# !python -m pip install .
# Out:
# Processing /content/models/research
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 53.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 94.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.3/47.3 MB 11.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.6/116.6 kB 16.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 76.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 6.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.2/241.2 kB 25.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 39.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 11.8 MB/s eta 0:00:00
# ...

# %%
# From within TensorFlow/models/research/
# !python object_detection/builders/model_builder_tf2_test.py
# Out:
# 2024-01-16 05:57:25.170699: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-16 05:57:25.170761: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-16 05:57:25.172886: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-16 05:57:26.677976: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Running tests under Python 3.10.12: /usr/bin/python3
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# ...

# %%
cd /content/training_demo/pre-trained-models
# Out:
# /content/training_demo/pre-trained-models

# %%
# !wget http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_resnet101_v1_fpn_640x640_coco17_tpu-8.tar.gz
# Out:
# --2024-01-16 05:58:23--  http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_resnet101_v1_fpn_640x640_coco17_tpu-8.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 173.194.206.207, 108.177.112.207, 74.125.124.207, ...
# Connecting to download.tensorflow.org (download.tensorflow.org)|173.194.206.207|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 386527459 (369M) [application/x-tar]
# Saving to: ‘ssd_resnet101_v1_fpn_640x640_coco17_tpu-8.tar.gz’
#
# ssd_resnet101_v1_fp 100%[===================>] 368.62M   175MB/s    in 2.1s
#
# 2024-01-16 05:58:25 (175 MB/s) - ‘ssd_resnet101_v1_fpn_640x640_coco17_tpu-8.tar.gz’ saved [386527459/386527459]

# %%
# !tar -xvf ssd_resnet101_v1_fpn_640x640_coco17_tpu-8.tar.gz
# Out:
# ssd_resnet101_v1_fpn_640x640_coco17_tpu-8/
# ssd_resnet101_v1_fpn_640x640_coco17_tpu-8/checkpoint/
# ssd_resnet101_v1_fpn_640x640_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# ssd_resnet101_v1_fpn_640x640_coco17_tpu-8/checkpoint/checkpoint
# ssd_resnet101_v1_fpn_640x640_coco17_tpu-8/checkpoint/ckpt-0.index
# ssd_resnet101_v1_fpn_640x640_coco17_tpu-8/pipeline.config
# ssd_resnet101_v1_fpn_640x640_coco17_tpu-8/saved_model/
# ssd_resnet101_v1_fpn_640x640_coco17_tpu-8/saved_model/saved_model.pb
# ssd_resnet101_v1_fpn_640x640_coco17_tpu-8/saved_model/assets/
# ssd_resnet101_v1_fpn_640x640_coco17_tpu-8/saved_model/variables/
# ssd_resnet101_v1_fpn_640x640_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001
# ssd_resnet101_v1_fpn_640x640_coco17_tpu-8/saved_model/variables/variables.index

# %%
pwd
# Out:
# '/content/training_demo/pre-trained-models'

# %%
cd /content/training_demo
# Out:
# /content/training_demo

# %%
ls
# Out:
# annotations/      exporter_main_v2.py         images/            models/
# exported-models/  export_tflite_graph_tf2.py  model_main_tf2.py  pre-trained-models/

# %% [markdown]
# ##**Configure the Training Pipeline**

# %%
training_demo/
├─ ...
├─ pre-trained-models/
│  └─ ssd_resnet50_v1_fpn_640x640_coco17_tpu-8/
│     ├─ checkpoint/
│     ├─ saved_model/
│     └─ pipeline.config
└─ ...

# %% [markdown]
# Here we have to genrate Tensorflow train and test record forthat we have provided a file link
# https://drive.google.com/file/d/1krWiPqRmXWNqIP_--b-4vEkf1-5F3IS7/view?usp=sharing
# ### make change in line 152 to your desired number of repition steps
# - make change in line 152 to your desired number of repition steps

# %%
# Create train data:
# !python generate_tfrecord.py -x /content/training_demo/images/train -l /content/training_demo/annotations/label_map.pbtxt -o /content/training_demo/annotations/train.record

# Create test data:
# !python generate_tfrecord.py -x /content/training_demo/images/test -l /content/training_demo/annotations/label_map.pbtxt -o /content/training_demo/annotations/test.record
# Out:
# 2024-01-16 05:59:27.547166: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-16 05:59:27.547208: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-16 05:59:27.548468: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Successfully created the TFRecord file: /content/training_demo/annotations/train.record
# 2024-01-16 05:59:31.943400: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
pwd
# Out:
# '/content/training_demo'

# %%
ls
# Out:
# annotations/         export_tflite_graph_tf2.py  model_main_tf2.py
# exported-models/     generate_tfrecord.py        models/
# exporter_main_v2.py  images/                     pre-trained-models/

# %%
# !pip install tensorflow==2.13.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 524.1/524.1 MB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 38.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 42.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.8/440.8 kB 39.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.15.0
#     Uninstalling tensorflow-estimator-2.15.0:
#       Successfully uninstalled tensorflow-estimator-2.15.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.15.0
#     Uninstalling keras-2.15.0:
#       Successfully uninstalled keras-2.15.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.4
#     Uninstalling gast-0.5.4:
#       Successfully uninstalled gast-0.5.4
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.2.0
# ...

# %% [markdown]
# #**Train the Model**
# Repetetions = 2000
# Improved version = 25000 steps more/less
#
#
# **Procedure for improvements**
#
# 1. follow Pipeline Config line Number
# 162  num_steps: 25000
# 2.train the Model for More repititions

# %%
# !python model_main_tf2.py --model_dir=/content/training_demo/models/my_ssd_resnet101_v1_fpn --pipeline_config_path=/content/training_demo/models/my_ssd_resnet101_v1_fpn/pipeline.config
# Out:
# 2024-01-16 06:12:03.414798: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-01-16 06:12:07.277266: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1960] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# I0116 06:12:07.279340 138197075685376 mirrored_strategy.py:419] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: None
# I0116 06:12:07.311457 138197075685376 config_util.py:552] Maybe overwriting train_steps: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# ...

# %%
pwd
# Out:
# '/content/training_demo'

# %% [markdown]
# ##**Exporting a Trained Model**
# Once your training job is complete, you need to extract the newly trained inference graph, which will be later used to perform the object detection. This can be done as follows:
#
# Copy the TensorFlow/models/research/object_detection/exporter_main_v2.py script and paste it straight into your training_demo folder

# %%
# !python exporter_main_v2.py --input_type image_tensor --pipeline_config_path /content/training_demo/models/my_ssd_resnet101_v1_fpn/pipeline.config --trained_checkpoint_dir /content/training_demo/models/my_ssd_resnet101_v1_fpn --output_directory /content/training_demo/exported_models/my_model
# Out:
# 2024-01-16 10:59:59.658254: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-01-16 11:00:02.510291: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1960] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py:459: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# ...

# %% [markdown]
# #**Inferencing My Trained Models**

# %%
"""
Object Detection (On Image) From TF2 Saved Model
=====================================
"""

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'    # Suppress TensorFlow logging (1)
import pathlib
import tensorflow as tf
import cv2
import argparse
from google.colab.patches import cv2_imshow

# Enable GPU dynamic memory allocation
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# PROVIDE PATH TO IMAGE DIRECTORY
IMAGE_PATHS = '/content/training_demo/images/train/image3.jpg'


# PROVIDE PATH TO MODEL DIRECTORY
PATH_TO_MODEL_DIR = '/content/training_demo/exported_models/my_model'

# PROVIDE PATH TO LABEL MAP
PATH_TO_LABELS = '/content/training_demo/annotations/label_map.pbtxt'

# PROVIDE THE MINIMUM CONFIDENCE THRESHOLD
MIN_CONF_THRESH = float(0.60)

# LOAD THE MODEL

import time
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils

PATH_TO_SAVED_MODEL = PATH_TO_MODEL_DIR + "/saved_model"

print('Loading model...', end='')
start_time = time.time()

# LOAD SAVED MODEL AND BUILD DETECTION FUNCTION
detect_fn = tf.saved_model.load(PATH_TO_SAVED_MODEL)

end_time = time.time()
elapsed_time = end_time - start_time
print('Done! Took {} seconds'.format(elapsed_time))

# LOAD LABEL MAP DATA FOR PLOTTING

category_index = label_map_util.create_category_index_from_labelmap(PATH_TO_LABELS,
                                                                    use_display_name=True)

import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')   # Suppress Matplotlib warnings

def load_image_into_numpy_array(path):
    """Load an image from file into a numpy array.
    Puts image into numpy array to feed into tensorflow graph.
    Note that by convention we put it into a numpy array with shape
    (height, width, channels), where channels=3 for RGB.
    Args:
      path: the file path to the image
    Returns:
      uint8 numpy array with shape (img_height, img_width, 3)
    """
    return np.array(Image.open(path))




print('Running inference for {}... '.format(IMAGE_PATHS), end='')

image = cv2.imread(IMAGE_PATHS)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image_expanded = np.expand_dims(image_rgb, axis=0)

# The input needs to be a tensor, convert it using `tf.convert_to_tensor`.
input_tensor = tf.convert_to_tensor(image)
# The model expects a batch of images, so add an axis with `tf.newaxis`.
input_tensor = input_tensor[tf.newaxis, ...]

# input_tensor = np.expand_dims(image_np, 0)
detections = detect_fn(input_tensor)

# All outputs are batches tensors.
# Convert to numpy arrays, and take index [0] to remove the batch dimension.
# We're only interested in the first num_detections.
num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
               for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

image_with_detections = image.copy()

# SET MIN_SCORE_THRESH BASED ON YOU MINIMUM THRESHOLD FOR DETECTIONS
viz_utils.visualize_boxes_and_labels_on_image_array(
      image_with_detections,
      detections['detection_boxes'],
      detections['detection_classes'],
      detections['detection_scores'],
      category_index,
      use_normalized_coordinates=True,
      max_boxes_to_draw=200,
      min_score_thresh=0.5,
      agnostic_mode=False)

print('Done')
# DISPLAYS OUTPUT IMAGE
cv2_imshow(image_with_detections)
# CLOSES WINDOW ONCE KEY IS PRESSED
# Out:
# Loading model...Done! Took 17.521880626678467 seconds
# Running inference for /content/training_demo/images/train/image3.jpg... Done
# <PIL.Image.Image image mode=RGB size=1920x1080>

# %% [markdown]
# #**My Model Result**
# In the image above, the model correctly identified the object as a car, showing that it's doing well. However, to make it even better, we should train the model for more steps. Right now, I trained it for only 2000 steps, and that took more than 6 hours. Training for a longer time and more steps could improve its accuracy and overall performance.

# %% [markdown]
# #**Navigating Challenges in Object Detection: A Journey Through Data Collection to GPU Connectivity**
#
# 1. **Data Collection and Labeling:**
#    - **Challenge:** Gathering a diverse and representative dataset for training.
#    - **Solution:** Utilized LabelImg tool for manual annotation, a time-consuming task requiring attention to detail.
#
# 2. **Command Prompt Execution:**
#    - **Challenge:** Navigating and running commands in the command prompt.
#    - **Solution:** Provided team members with detailed command instructions, ensuring proper execution.
#
# 3. **Prerequisite Installation:**
#    - **Challenge:** Installing necessary prerequisites, including TensorFlow and other dependencies.
#    - **Solution:** Shared step-by-step guides and troubleshooting tips for smooth installations.
#
# 4. **Compilation and Model Setup:**
#    - **Challenge:** Compiling Protobuf files and setting up the model in the correct directory structure.
#    - **Solution:** Provided a clear directory tree and instructions, minimizing errors during setup.
#
# 5. **Utilizing TensorFlow Directory Structure:**
#    - **Challenge:** Adhering to the TensorFlow directory structure for compatibility.
#    - **Solution:** Emphasized the importance of following the recommended directory structure for seamless integration.
#
# 6. **Installing Pretrained Models:**
#    - **Challenge:** Installing and configuring pretrained models.
#    - **Solution:** Detailed instructions and guidance on downloading and integrating pretrained models for object detection.
#
# 7. **Exporting and Training Duration:**
#    - **Challenge:** Managing the export process and training the model for an extended duration.
#    - **Solution:** Emphasized the need for patience during training and provided insights into potential challenges.
#
# 8. **GPU Connectivity Issues:**
#    - **Challenge:** Addressing GPU connectivity issues, including disconnections during long training sessions.
#    - **Solution:** Shared tips on handling GPU interruptions, such as reconnecting and resuming training.
